# %% [markdown]
# <a href="https://colab.research.google.com/github/suraj-ranganath/BIF-birthday-wishes/blob/master/Drug_discovery_for_SARS_coronavirus2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 55 kB 2.2 MB/s
# ...
#      |████████████████████████████████| 596 kB 11.4 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.1.2 which is incompatible.
# ...

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
#search for target protein in db
target = new_client.target
target_query = target.search("coronavirus")
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...
# 5                                                 []
# 6  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...
# 7                                                 []
#
#                                             organism  \
# 0                                        Coronavirus
# 1                                   SARS coronavirus
# 2                                 Feline coronavirus
# 3                             Human coronavirus 229E
# 4                                   SARS coronavirus
# 5  Middle East respiratory syndrome-related coron...
# 6                                   SARS coronavirus
# 7    Severe acute respiratory syndrome coronavirus 2
#
# ...

# %%
#selecting Replicase Polyprotein 1ab for SARS Covid 2
selected_target = targets.target_chembl_id[7]
selected_target
# Out:
# 'CHEMBL4523582'

# %%
#Only bioactivity data is filtered out
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")
df = pd.DataFrame.from_dict(res)
df.head()
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0  Dtt Insensitive     19964199                  []   CHEMBL4495583
# 1  Dtt Insensitive     19964200                  []   CHEMBL4495583
# 2  Dtt Insensitive     19964201                  []   CHEMBL4495583
# 3  Dtt Insensitive     19964202                  []   CHEMBL4495583
# 4  Dtt Insensitive     19964203                  []   CHEMBL4495583
#
#                                    assay_description assay_type  \
# 0  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 1  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 2  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 3  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
# 4  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...          F
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000019
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
#lower the val higher the potensy of the drug
df.standard_value
# Out:
# 0       390.0
# 1       210.0
# 2        80.0
# 3      1580.0
# 4        40.0
#         ...
# 112    1240.0
# 113    4980.0
# 114     750.0
# 115     880.0
# 116    1930.0
# Name: standard_value, Length: 117, dtype: object
